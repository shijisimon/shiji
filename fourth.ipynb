# %% [markdown]
# # Read any data frame and plot Pie chart(using bothMatplotlib and Seaborn)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('police.csv')
df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %% [markdown]
# #  plot Pie chart using Matplotlib

# %%
 df['violation'].value_counts().plot.pie()

plt.show()

# %% [markdown]
# # plot Pie chart using Seaborn

# %%
import seaborn as sns
sns.set_theme(palette="dark",font="arial",font_scale=2)
data=[211000,183300,224700,222700,209600,201400,295500,361400,234000,267000,412800,310000]
months=["January","February","March","April","May","June","July","August","September","October","November","December"]
plt.pie(data,labels=months)
plt.show()
