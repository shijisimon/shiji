# %%
import pandas as pd
data1=pd.read_csv('police.csv')
data1
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %% [markdown]
# # 2.MEAN SD AND MAX of each first two numerical coloumns and show it separately

# %%
data1['driver_age'].describe()
# Out:
# count    86120.000000
# mean        34.011333
# std         12.738564
# min         15.000000
# 25%         23.000000
# 50%         31.000000
# 75%         43.000000
# max         99.000000
# Name: driver_age, dtype: float64

# %%
data1['driver_age_raw'].describe()
# Out:
# count    86414.000000
# mean      1970.491228
# std        110.914909
# min          0.000000
# 25%       1967.000000
# 50%       1980.000000
# 75%       1987.000000
# max       8801.000000
# Name: driver_age_raw, dtype: float64
